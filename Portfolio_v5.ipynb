# %%
import pandas as pd
import numpy as np
import yfinance as yf

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

start_date = "2021-12-31"
end_date   = "2025-12-31"

# %%
url='https://raw.githubusercontent.com/BoraY888/AI-Value-Chain-Portfolio-Optimisation/e56449b489957421500cfd7b6eb46c63bdb2ccec/port_data_usd.csv'

port_data_usd = pd.read_csv(url, index_col=0, parse_dates=True)

combined_ret = port_data_usd.pct_change()
# Out:
# /tmp/ipykernel_15111/300018956.py:5: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   combined_ret = port_data_usd.pct_change()

# %%
combined_ret.head(100)
# Out:
#                  ADI  ALAB      AMAT       AMD      ASML      AVGO      CRDO  \
# Date
# 2021-12-31       NaN   NaN       NaN       NaN       NaN       NaN       NaN
# 2022-01-02  0.000000   NaN  0.000000  0.000000  0.000000  0.000000       NaN
# 2022-01-03  0.007851   NaN  0.016332  0.044058  0.001696 -0.003141       NaN
# 2022-01-04 -0.009032   NaN -0.009817 -0.038738 -0.022947  0.011458       NaN
# 2022-01-05 -0.015437   NaN -0.029174 -0.057264 -0.043019 -0.041614       NaN
# 2022-01-06  0.003182   NaN  0.016912  0.000588  0.023402 -0.009285       NaN
# 2022-01-07 -0.026241   NaN -0.035372 -0.031050 -0.009199 -0.028068       NaN
# 2022-01-09  0.000000   NaN  0.000000  0.000000  0.000000  0.000000       NaN
# 2022-01-10  0.009240   NaN -0.008090  0.000000 -0.038262  0.003246       NaN
# 2022-01-11  0.018955   NaN  0.019119  0.040227  0.002737  0.001433       NaN
# 2022-01-12  0.000691   NaN  0.046573  0.001165  0.017842 -0.000080       NaN
# 2022-01-13 -0.022849   NaN -0.014854 -0.034407 -0.016290 -0.039887       NaN
# 2022-01-14  0.013076   NaN  0.062476  0.031189  0.019792 -0.001373       NaN
# 2022-01-16  0.000000   NaN  0.000000  0.000000  0.000000  0.000000       NaN
# 2022-01-17  0.000000   NaN  0.000000  0.000000  0.000000  0.000000       NaN
# 2022-01-18 -0.031977   NaN -0.087665 -0.036163 -0.039354 -0.031155       NaN
# 2022-01-19 -0.020661   NaN -0.060974 -0.027742 -0.022944 -0.023919       NaN
# 2022-01-20 -0.027168   NaN -0.027399 -0.049739  0.010933 -0.028814       NaN
# 2022-01-21  0.005611   NaN -0.029393 -0.025269 -0.016604 -0.026455       NaN
# 2022-01-23  0.000000   NaN  0.000000  0.000000  0.000000  0.000000       NaN
# 2022-01-24  0.012036   NaN  0.031319 -0.019190 -0.010522  0.015659       NaN
# 2022-01-25 -0.035121   NaN -0.045229 -0.046340 -0.056516 -0.013738       NaN
# 2022-01-26  0.025679   NaN  0.019475 -0.003779  0.007231  0.043022       NaN
# 2022-01-27 -0.032422   NaN -0.040050 -0.073254 -0.028473 -0.026583       NaN
# 2022-01-28  0.026134   NaN  0.017672  0.025731  0.016245  0.032804 -0.039485
# 2022-01-30  0.000000   NaN  0.000000  0.000000  0.000000  0.000000  0.000000
# 2022-01
# 2022-04-03  0.000000  0.000000  0.000000
# 2022-04-04  0.004983  0.020140 -0.006173
# 2022-04-05 -0.037184 -0.013162 -0.044168
# 2022-04-06  0.008754 -0.018187 -0.013718
# 2022-04-07 -0.005105  0.008027 -0.013909
# 2022-04-08 -0.005131  0.005207  0.005197
# 2022-04-10  0.000000  0.000000  0.000000
# 2022-04-11 -0.024755 -0.024071 -0.042836
# 2022-04-12  0.008990  0.021542 -0.045525
# 2022-04-13  0.021488  0.023227  0.060631
# 2022-04-14  0.000513  0.008363 -0.056402
# 2022-04-15  0.000000  0.000000  0.000000
# 2022-04-17  0.000000  0.000000  0.000000
# 2022-04-18  0.012308  0.014810 -0.025848
# 2022-04-19  0.025836 -0.005838  0.083748
# 2022-04-20  0.014321  0.013506 -0.013007
# 2022-04-21 -0.000487 -0.035342 -0.035659
# 2022-04-22  0.002923 -0.030030 -0.065112
# 2022-04-24  0.000000  0.000000  0.000000
# 2022-04-25  0.005828 -0.032198  0.036973
# 2022-04-26 -0.014003  0.013436 -0.043118

# %%
ticker_list = combined_ret.columns.tolist()

metadata_list = []

for ticker in ticker_list:
    try:
        info = yf.Ticker(ticker).info
        metadata_list.append({
            "ticker": ticker,
            "sector": info.get("sector"),
            "industry": info.get("industry")
        })
    except Exception:
        metadata_list.append({"ticker": ticker, "sector": "N/A", "industry": "N/A"})

stock_metadata = pd.DataFrame(metadata_list)

stock_metadata = stock_metadata.set_index("ticker")

print(stock_metadata['industry'])
# Out:
# ERROR:yfinance:HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"Quote not found for symbol: FVJA.BE"}}}
# ERROR:yfinance:HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"Quote not found for symbol: HWHG.BE"}}}
# ERROR:yfinance:HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"Quote not found for symbol: IZ1.BE"}}}
# ERROR:yfinance:HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"Quote not found for symbol: PKX.BE"}}}
# ERROR:yfinance:HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"Quote not found for symbol: 66T.BE"}}}
# ERROR:yfinance:HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"Quote not found for symbol: AOR.BE"}}}
# ERROR:yfinance:HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"Quote not found for symbol: S93.BE"}}}
# ticker
# ADI                                     Semiconductors
# ALAB                                    Semiconductors
# AMAT               Semiconductor Equipment & Materials
# AMD                                     Semiconductors
# ASML               Semiconductor Equipment & Materials
# AVGO                                    Semiconductors
# CRDO                                    Semiconductors
# ENTG               Semiconductor Equipment & Materials
# INTC                                    Semiconductors
# KLAC               Semiconductor Equipment & Materials
# LRCX               Semiconductor Equipment & Materials
# MCHP                                    Semiconductors
# MPWR                                    Semiconductors
# MRVL                                    Semiconductors
# MTSI                                    Semiconductors
# MU                                      Semiconductors
# NVDA                                    Semiconductors
# NVMI               Semiconductor Equipment & Materials
# NXPI                                    Semiconductors
# ON                                      Semiconductors
# QCOM                                    Semiconductors
# RMBS                                    Semiconductors
# TER                Semiconductor Equipment & Materials
# TSM                                     Semiconductors
# TXN                                     Semiconductors
# 1211.SR               Other Industrial Metals & Mining
# AA                                            Aluminum
# AAL                                           Airlines
# ANTO.L                                          Copper
# BHP                   Other Industrial Metals & Mining
# BWJ0.F                Other Industrial Metals & Mining
# FCX                                             Copper
# FVJA.BE                                           None
# GLNCY                 Other Industrial Metals & Mining
# GMEXICOB.MX           Other Industrial Metals & Mining
# GXD.F                                           Copper
# EQIX                                  REIT - Specialty
# GDS                    Information Technology Services
# SBAC                                  REIT - Specialty
# SMCI                                 Computer Hardware
# UNIT                                  REIT - Specialty
# VNET                   Information Technology Services
# ABJA.MU                                           None
# AEIS                      Electrical Equipment & Parts
# APH                              Electronic Components
# BELFB                            Electronic Components
# BWXT                               Aerospace & Defense
# CAT                Farm & Heavy Construction Machinery
# ET                                 Oil & Gas Midstream
# GEV                     Specialty Industrial Machinery
# IDA                     Utilities - Regulated Electric
# ITRI                Scientific & Technical Instruments
# JCI                      Building Products & Equipment
# NI                           Utilities - Regulated Gas
# NVT                       Electrical Equipment & Parts
# OGE                     Utilities - Regulated Electric
# POWL                      Electrical Equipment & Parts
# SU                                Oil & Gas Integrated
# VRT                       Electrical Equipment & Parts
# Name: industry, dtype: object

# %%
stock_metadata['industry'].unique()
# Out:
# array(['Semiconductors', 'Semiconductor Equipment & Materials',
#        'Other Industrial Metals & Mining', 'Aluminum', 'Airlines',
#        'Copper', None, 'Other Precious Metals & Mining', 'Steel',
#        'Utilities - Regulated Electric', 'Utilities - Regulated Gas',
#        'Utilities - Regulated Water',
#        'Utilities - Independent Power Producers',
#        'Utilities - Diversified', 'Building Materials', 'Railroads',
#        'Farm & Heavy Construction Machinery',
#        'Engineering & Construction', 'Specialty Industrial Machinery',
#        'Industrial Distribution', 'Scientific & Technical Instruments',
#        'Electrical Equipment & Parts', 'Aerospace & Defense',
#        'Building Products & Equipment', 'Rental & Leasing Services',
#        'Solar', 'Utilities - Renewable', 'Asset Management',
#        'Telecom Services', 'Real Estate Services', 'REIT - Office',
#        'REIT - Specialty', 'Information Technology Services',
#        'Computer Hardware', 'Electronic Components',
#        'Oil & Gas Midstream', 'Oil & Gas Integrated'], dtype=object)

# %%
industry_map = {
    # 1. Semiconductors
    'Semiconductors': 'Semiconductors',
    'Semiconductor Equipment & Materials': 'Semiconductors',
    'Electronic Components': 'Semiconductors', # Often logic/memory chips

    # 2. Metals and Mining
    'Other Industrial Metals & Mining': 'Metals and Mining',
    'Aluminum': 'Metals and Mining',
    'Copper': 'Metals and Mining',
    'Steel': 'Metals and Mining',
    'Other Precious Metals & Mining': 'Metals and Mining',

    # 3. Utilities (The Power Grid)
    'Utilities - Regulated Electric': 'Utilities',
    'Utilities - Regulated Gas': 'Utilities',
    'Utilities - Regulated Water': 'Utilities',
    'Utilities - Independent Power Producers': 'Utilities',
    'Utilities - Diversified': 'Utilities',
    'Oil & Gas Midstream': 'Utilities',
    'Oil & Gas Integrated': 'Utilities',

    # 4. Renewable Energy (The "Green" AI requirement)
    'Solar': 'Renewable Energy',
    'Utilities - Renewable': 'Renewable Energy',

    # 5. Data Center Infrastructure (The Physical Shell & Connectivity)
    'REIT - Specialty': 'Data Center Infrastructure',
    'Information Technology Services': 'Data Center Infrastructure',
    'Telecom Services': 'Data Center Infrastructure',
    'Computer Hardware': 'Data Center Infrastructure',
    'Electrical Equipment & Parts': 'Data Center Infrastructure',
    'Engineering & Construction': 'Data Center Infrastructure',
    'Building Products & Equipment': 'Data Center Infrastructure',
    'Specialty Industrial Machinery': 'Data Center Infrastructure',
    'Building Materials': 'Data Center Infrastructure',
    'Real Estate Services': 'Data Center Infrastructure',
    'REIT - Office': 'Data Center Infrastructure',
    'Rental & Leasing Services': 'Data Center Infrastructure',
    'Scientific & Technical Instruments': 'Data Center Infrastructure'
}

# 2. Apply it to your metadata dataframe
stock_metadata['valchain_industry'] = stock_metadata['industry'].map(industry_map)

# 3. Fill anything that didn't match as "Other"
stock_metadata['valchain_industry'] = stock_metadata['valchain_industry'].fillna('Other')

# %%
# !pip install arch
from arch import arch_model

egarch_results = {}
min_obs = 500

for col in combined_ret.columns:
    series = combined_ret[col].dropna()

    if len(series) < min_obs:
      print(f"{col}: Insufficient Data - {len(series)} Days of Returns")
      continue

    model = arch_model(
        series,           #arch_model requires 1D input
        p=1,              #p is the number of lagged/delayed log-volatility terms. Represents how long it takes shock-induced volatility to decay (1=yesterday's forecast)
        o=1,              #o is the asymmetric term. Captures the leverage effect (bad news increases volatility more than good news)
        q=1,              #q is the number of lagged residuals/errors. Represents how impactful the news is on volatility (1=yesterday's news)
        mean='constant',  #Mean does not change over time (Assumption)
        vol='EGARCH',     #EGARCH (Exponential GARCH) models the log of variance, allowing for asymmetric shocks with "o" variable
        dist='normal',    #Assume returns are normally distributed
        rescale=True      #Tiny daily returns such as 0.15% squared cause variance calculations to fail as computer loses precision
    )                     #GARCH(p=2, q=2) or over often overfits

    res = model.fit(disp="off", show_warning=False)
    if res.convergence_flag == 0:
      egarch_results[col] = res
      forecast = res.forecast(horizon=21, method='simulation')  #EGARCH is non-linear, so no analytical solution, therefore Monte-Carlo simulation used
      print(f"{col} modelled successfully")
    else:
      print(f"{col} did not converge")

print(f"\nFinal count of modeled stocks: {len(egarch_results)}")
# Out:
# Requirement already satisfied: arch in /usr/local/lib/python3.12/dist-packages (8.0.0)
# Requirement already satisfied: numpy<3,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from arch) (2.0.2)
# Requirement already satisfied: pandas>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from arch) (2.2.2)
# Requirement already satisfied: scipy>=1.8 in /usr/local/lib/python3.12/dist-packages (from arch) (1.16.3)
# Requirement already satisfied: statsmodels>=0.13.0 in /usr/local/lib/python3.12/dist-packages (from arch) (0.14.6)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from arch) (26.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.4.0->arch) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.4.0->arch) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.4.0->arch) (2026.1)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.12/dist-packages (from statsmodels>=0.13.0->arch) (1.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.4.0->arch) (1.17.0)
# ADI modelled successfully
# ALAB modelled successfully
# AMAT modelled successfully
# AMD modelled successfully
# ASML modelled successfully
# AVGO modelled successfully
# CRDO modelled successfully
# ENTG modelled successfully
# INTC modelled successfully
# KLAC modelled successfully
# LRCX modelled successfully
# MCHP modelled successfully
# MPWR modelled successfully
# MRVL modelled successfully
# MTSI modelled successfully
# MU modelled successfully
# NVDA modelled successfully
# NVMI modelled successfully
# NXPI modelled successfully
# ON modelled successfully
# QCOM modelled successfully
# RMBS modelled successfully
# TER modelled successfully
# TSM modelled successfully
# TXN modelled successfully
# 1211.SR modelled successfully
# AA modelled successfully
# AAL modelled successfully
# ANTO.L modelled successfully
# BHP modelled successfully
# BWJ0.F modelled successfully
# FCX modelled successfully
# FVJA.BE: Insufficient Data - 0 Days of Returns
# GLNCY modelled successfully
# GMEXICOB.MX modelled successfully
# GXD.F modelled successfully
# HWHG.BE: Insufficient Data - 0 Days of Returns
# IPHB.F modelled successfully
# IZ1.BE: Insufficient Data - 0 Days of Returns
# MT modelled successfully
# NPS.MU modelled successfully
# NUE did not converge
# PKX.BE: Insufficient Data - 0 Days of Returns
# RIO modelled successfully
# RS modelled successfully
# STLD modelled successfully
# TECK modelled successfully
# VALE modelled successfully
# VALT.L modelled successfully
# AEE modelled successfully
# AEP modelled successfully
# ATO modelled successfully
# AWK modelled successfully
# CEG modelled successfully
# CNP modelled successfully
# D modelled successfully
# DTE modelled successfully
# DUK modelled successfully
# ED modelled successfully
# EIX modelled successfully
# ES modelled successfully
# ETR modelled successfully
# EXC modelled successfully
# FE modelled successfully
# NEE modelled successfully
# NRG modelled successfully
# PCG modelled successfully
# PEG modelled successfully
# PPL modelled successfully
# SO modelled successfully
# SRE modelled successfully
# VST modelled successfully
# WEC modelled successfully
# XEL modelled successfully
# CRH modelled successfully
# CSX modelled successfully
# DE modelled successfully
# EME modelled successfully
# EMR modelled successfully
# ETN modelled successfully
# FAST modelled successfully
# FTV modelled successfully
# HUBB modelled successfully
# HWM modelled successfully
# MLM modelled successfully
# MTZ modelled successfully
# NSC modelled successfully
# PH modelled successfully
# PWR modelled successfully
# ROK did not converge
# TRMB modelled successfully
# TT modelled successfully
# UNP modelled successfully
# URI modelled successfully
# VMC modelled successfully
# WWD modelled successfully
# 6443.TW modelled successfully
# 66T.BE: Insufficient Data - 0 Days of Returns
# AOR.BE: Insufficient Data - 0 Days of Returns
# ARRY modelled successfully
# CSIQ modelled successfully
# CWEN modelled successfully
# DORL.TA modelled successfully
# DQ modelled successfully
# ENLT modelled successfully
# ENPH modelled successfully
# ENRG.TA modelled successfully
# FGSGF did not converge
# FSLR modelled successfully
# GCPEF modelled successfully
# GRE.MC modelled successfully
# HASI modelled successfully
# JKS modelled successfully
# NOFR.TA modelled successfully
# NXT modelled successfully
# RUN modelled successfully
# S93.BE: Insufficient Data - 0 Days of Returns
# SEDG modelled successfully
# SHLS modelled successfully
# XNYIF modelled successfully
# 000660.KS did not converge
# 0788.HK modelled successfully
# 1686.HK modelled successfully
# 2344.TW modelled successfully
# 3006.TW modelled successfully
# AJBU.SI modelled successfully
# AMT modelled successfully
# APLD modelled successfully
# ARM modelled successfully
# CCI modelled successfully
# DLR modelled successfully
# EQIX modelled successfully
# GDS modelled successfully
# SBAC did not converge
# SMCI modelled successfully
# UNIT modelled successfully
# VNET modelled successfully
# ABJA.MU did not converge
# AEIS modelled successfully
# APH modelled successfully
# BELFB modelled successfully
# BWXT modelled successfully
# CAT modelled successfully
# ET modelled successfully
# GEV modelled successfully
# IDA modelled successfully
# ITRI modelled successfully
# JCI modelled successfully
# NI modelled successfully
# NVT modelled successfully
# OGE modelled successfully
# POWL modelled successfully
# SU modelled successfully
# VRT modelled successfully
#
# Final count of modeled stocks: 141

# %%
#Removing stocks with insufficient data and Non-Converging stocks as EGARCH couldn't find a stable solution for volatility
combined_ret_filtered = combined_ret.drop(columns=['S93.BE', '66T.BE', 'AOR.BE', 'PKX.BE', 'IZ1.BE', 'HWHG.BE', 'FVJA.BE',
                                                   'ABJA.MU', 'SBAC', '000660.KS', 'FGSGF', 'ROK', 'NUE'])

# %%
trad_month_vols = {}

for col, res in egarch_results.items():
    forecast = res.forecast(horizon=21, method='simulation')
    trading_month_vol = np.sqrt(forecast.variance.iloc[-1].sum())
    trad_month_vols[col] = trading_month_vol

# %%
annual_sharpe = (combined_ret.mean() / combined_ret.std()) * np.sqrt(252)

valchain_df = stock_metadata.copy()
valchain_df['Sharpe'] = annual_sharpe
valchain_df['EGARCH_vol'] = pd.Series(trad_month_vols)

valchain_df = valchain_df[valchain_df['valchain_industry'] != 'Other']

final_selection = []

for industry in valchain_df['valchain_industry'].unique():
  subset = valchain_df[valchain_df['valchain_industry'] == industry].copy()

  vol_cutoff = subset['EGARCH_vol'].quantile(0.8)      #Removing top 20% of stocks with highest volatility
  stable_stocks = subset[subset['EGARCH_vol'] <= vol_cutoff]

  top_5 = stable_stocks.nlargest(5, 'Sharpe')         #Top 5 per AI Value Chain Industry for Sharpe Ratio
  final_selection.append(top_5)

port_data_25 = pd.concat(final_selection)

# %%
port_data_25.head(25)
# Out:
#                       sector                          industry  \
# ticker
# CRDO              Technology                    Semiconductors
# AVGO              Technology                    Semiconductors
# APH               Technology             Electronic Components
# NVDA              Technology                    Semiconductors
# ALAB              Technology                    Semiconductors
# STLD         Basic Materials                             Steel
# GXD.F        Basic Materials                            Copper
# GMEXICOB.MX  Basic Materials  Other Industrial Metals & Mining
# RS           Basic Materials                             Steel
# TECK         Basic Materials  Other Industrial Metals & Mining
# ET                    Energy               Oil & Gas Midstream
# ATO                Utilities         Utilities - Regulated Gas
# ETR                Utilities    Utilities - Regulated Electric
# NI                 Utilities         Utilities - Regulated Gas
# CNP                Utilities    Utilities - Regulated Electric
# EME              Industrials        Engineering & Construction
# POWL             Industrials      Electrical Equipment & Parts
# VRT              Industrials      Electrical Equipment & Parts
# PH               Industrials    Specialty Industrial Machinery
# SMCI              Technology                 Computer Hardware
# NXT               Technology                             Solar
# ENLT               Utilities             Utilities - Renewable
# GCPEF             Technology                             Solar
# RUN               Technology                             Solar
# ENRG.TA            Utilities             Utilities - Renewable
#
#                       valchain_industry    Sharpe  EGARCH_vol
# ticker
# CRDO                     Semiconductors  1.093634    2.207104
# AVGO                     Semiconductors  1.030796   11.847040
# APH                      Semiconductors  1.026510    8.360538
# NVDA                     Semiconductors  1.016792   12.821918
# ALAB                     Semiconductors  0.966477    2.035648
# STLD                  Metals and Mining  0.773823    7.988411
# GXD.F                 Metals and Mining  0.667602   11.625729
# GMEXICOB.MX           Metals and Mining  0.622699    9.918424
# RS                    Metals and Mining  0.593597    7.292827
# TECK                  Metals and Mining  0.456835   10.322283
# ET                            Utilities  0.743300    4.964352
# ATO                           Utilities  0.656265    4.787971
# ETR                           Utilities  0.602812    6.012442
# NI                            Utilities  0.551865    5.308850
# CNP                           Utilities  0.457274    4.940816
# EME          Data Center Infrastructure  1.214891    8.641566
# POWL         Data Center Infrastructure  1.092430    1.773622
# VRT          Data Center Infrastructure  0.959042    1.752393
# PH           Data Center Infrastructure  0.927467    6.147696
# SMCI         Data Center Infrastructure  0.877782    2.088737
# NXT                    Renewable Energy  0.815637    1.327530
# ENLT                   Renewable Energy  0.654224    0.813091
# GCPEF                  Renewable Energy  0.524995    8.816544
# RUN                    Renewable Energy  0.283989    2.523857
# ENRG.TA                Renewable Energy  0.275770    9.688379

# %%
port_data_25_tickers = port_data_25.index.tolist()

port_data_25_prices = port_data_usd[port_data_25_tickers]

port_data_25_prices = port_data_25_prices.ffill().dropna()

# %%
# !pip install mgarch     #DCC-GARCH not available in arch library
import mgarch

dcc_returns = port_data_25_prices.pct_change().dropna()

dist_model = mgarch.mgarch()     #Initialise multivariate GARCH with same distribution assumption as EGARCH

dist_model.fit(dcc_returns)         #Calculates conditional variance for each stock and dynamic correlations between them

prediction = dist_model.predict(1)     #Removes static covariance matrix, finds risk state at January 1st 2026

dcc_cov_matrix = prediction['cov']

#RESCALING
dcc_vols = np.sqrt(np.diag(dcc_cov_matrix))
dcc_corr = dcc_cov_matrix / np.outer(dcc_vols, dcc_vols)    #Extracting correlation matrix (Corr = Cov / Std_i * Std_j)

real_daily_vols = dcc_returns.std().values

corrected_daily_cov = np.outer(real_daily_vols, real_daily_vols) * dcc_corr     #Scale-Correccted Daily Covariance, Sigma = Vol_Matrix * Correlation_Matrix * Vol_Matrix

sigma_annualised = corrected_daily_cov * 252

dcc_sigma = pd.DataFrame(sigma_annualised, index=port_data_25_tickers, columns=port_data_25_tickers)    #Conversion to DataFrame for PyPortfolioOpt
# Out:
# Requirement already satisfied: mgarch in /usr/local/lib/python3.12/dist-packages (0.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mgarch) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mgarch) (1.16.3)

# %%
dcc_cov_matrix.shape
# Out:
# (25, 25)

# %%
# !pip install PyPortfolioOpt
from pypfopt import risk_models
from pypfopt import expected_returns
from pypfopt.efficient_frontier import EfficientFrontier

mu = expected_returns.mean_historical_return(port_data_25_prices)

sigma = dcc_sigma

ef = EfficientFrontier(mu, sigma)
print(mu,sigma)
# Out:
# Requirement already satisfied: PyPortfolioOpt in /usr/local/lib/python3.12/dist-packages (1.6.0)
# Requirement already satisfied: cvxpy>=1.1.19 in /usr/local/lib/python3.12/dist-packages (from PyPortfolioOpt) (1.6.7)
# Requirement already satisfied: numpy<3.0.0,>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from PyPortfolioOpt) (2.0.2)
# Requirement already satisfied: pandas<4.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from PyPortfolioOpt) (2.2.2)
# Requirement already satisfied: scikit-base<0.14.0 in /usr/local/lib/python3.12/dist-packages (from PyPortfolioOpt) (0.13.2)
# Requirement already satisfied: scikit-learn>=0.24.1 in /usr/local/lib/python3.12/dist-packages (from PyPortfolioOpt) (1.6.1)
# Requirement already satisfied: scipy>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from PyPortfolioOpt) (1.16.3)
# Requirement already satisfied: osqp>=0.6.2 in /usr/local/lib/python3.12/dist-packages (from cvxpy>=1.1.19->PyPortfolioOpt) (1.1.1)
# Requirement already satisfied: clarabel>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from cvxpy>=1.1.19->PyPortfolioOpt) (0.11.1)
# Requirement already satisfied: scs>=3.2.4.post1 in /usr/local/lib/python3.12/dist-packages (from cvxpy>=1.1.19->PyPortfolioOpt) (3.2.11)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<4.0.0,>=1.0.0->PyPortfolioOpt) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<4.0.0,>=1.0.0->PyPortfolioOpt) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<4.0.0,>=1.0.0->PyPortfolioOpt) (2026.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.24.1->PyPortfolioOpt) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.24.1->PyPortfolioOpt) (3.6.0)
# Requirement already satisfied: cffi in /usr/local/lib/python3.12/dist-packages (from clarabel>=0.5.0->cvxpy>=1.1.19->PyPortfolioOpt) (2.0.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from osqp>=0.6.2->cvxpy>=1.1.19->PyPortfolioOpt) (3.1.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from osqp>=0.6.2->cvxpy>=1.1.19->PyPortfolioOpt) (75.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas<4.0.0,>=1.0.0->PyPortfolioOpt) (1.17.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi->clarabel>=0.5.0->cvxpy>=1.1.19->PyPortfolioOpt) (3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->osqp>=0.6.2->cvxpy>=1.1.19->PyPortfolioOpt)
# ENRG.TA      0.002386  0.001470 -0.001508  0.012372  0.014114  0.004928
#
#                    PH      SMCI       NXT      ENLT     GCPEF       RUN  \
# CRDO         0.024122  0.258593  0.117999  0.114994  0.023776  0.143556
# AVGO         0.029152  0.172439  0.095637  0.052960  0.016141  0.118692
# APH          0.023136  0.101680  0.075494  0.045157 -0.016213  0.071340
# NVDA         0.016504  0.154922  0.073208  0.045415 -0.005103  0.080940
# ALAB         0.060113  0.280302  0.175801  0.076276 -0.021396  0.219964
# STLD         0.017690  0.012275  0.031184  0.018065  0.000564  0.064624
# GXD.F        0.020809 -0.039541  0.022798  0.038171  0.124386  0.046398
# GMEXICOB.MX  0.019510 -0.018034  0.047403  0.049100  0.006888  0.102695
# RS           0.011023 -0.021964  0.018888  0.005340  0.041732  0.044415
# TECK         0.003523 -0.007161  0.029110  0.037340 -0.025290  0.024002
# ET          -0.007235  0.008677 -0.033197  0.013256  0.079104 -0.050254
# ATO          0.004045 -0.038966 -0.003195  0.003806 -0.025128 -0.006126
# ETR          0.006530  0.003762  0.023129  0.020180 -0.004182  0.025492
# NI           0.005422 -0.014580  0.019359  0.020856 -0.018579  0.030028
# CNP         -0.006213 -0.037104 -0.012425  0.000218  0.000384 -0.006653
# EME          0.027357  0.095485  0.106300  0.039385 -0.008247  0.147706
# POWL         0.042928  0.199023  0.179257  0.030304 -0.031067  0.218421
# VRT          0.049958  0.185684  0.156209  0.067511  0.030230  0.199379
# PH           0.071654  0.037233  0.049975  0.018450 -0.025839  0.071016
# SMCI         0.037233  0.772489  0.130072  0.013879  0.123387  0.160836
# NXT          0.049975  0.130072  0.298523  0.033980 -0.040724  0.277058
# ENLT         0.018450  0.013879  0.033980  0.137282  0.072979  0.065025
# GCPEF       -0.025839  0.123387 -0.040724  0.072979  2.817685  0.082309
# RUN          0.071016  0.160836  0.277058  0.065025  0.082309  0.836945
# ENRG.TA      0.002227 -0.009411 -0.005010  0.040095  0.096226  0.005295
#
#               ENRG.TA
# CRDO        -0.009009
# AVGO         0.012143
# APH          0.007007
# NVDA         0.027624
# ALAB         0.005221
# STLD         0.013578
# GXD.F        0.040248
# GMEXICOB.MX  0.025341
# RS           0.006570
# TECK         0.025628
# ET           0.003473
# ATO         -0.002124
# ETR          0.002386
# NI           0.001470
# CNP         -0.001508
# EME          0.012372
# POWL         0.014114
# VRT          0.004928
# PH           0.002227
# SMCI        -0.009411
# NXT         -0.005010
# ENLT         0.040095
# GCPEF        0.096226
# RUN          0.005295
# ENRG.TA      0.092266

# %%
raw_weights_maxsharpe = ef.max_sharpe()           #Sharpe ratio = (Expected Return - Risk Free Return (usually 0 or close)) / Portfolio Volatility
cleaned_weights_maxsharpe = ef.clean_weights()    #Measures portfolio return per unit of volatility
print(raw_weights_maxsharpe, cleaned_weights_maxsharpe)
# Out:
# OrderedDict({'CRDO': 0.0811563943526719, 'AVGO': 0.0140162241063723, 'APH': 0.1197144142531523, 'NVDA': 0.0066711828524489, 'ALAB': 0.0, 'STLD': 0.0155027645836327, 'GXD.F': 0.0704997817694584, 'GMEXICOB.MX': 0.0, 'RS': 0.0, 'TECK': 0.0, 'ET': 0.0, 'ATO': 0.3579872494950429, 'ETR': 0.015928057441359, 'NI': 0.0, 'CNP': 0.2358474073209646, 'EME': 0.0, 'POWL': 0.0053804131902976, 'VRT': 0.0, 'PH': 0.030949835165641, 'SMCI': 0.0, 'NXT': 0.0, 'ENLT': 0.0, 'GCPEF': 0.0, 'RUN': 0.0, 'ENRG.TA': 0.0463462754689582}) OrderedDict({'CRDO': 0.08116, 'AVGO': 0.01402, 'APH': 0.11971, 'NVDA': 0.00667, 'ALAB': 0.0, 'STLD': 0.0155, 'GXD.F': 0.0705, 'GMEXICOB.MX': 0.0, 'RS': 0.0, 'TECK': 0.0, 'ET': 0.0, 'ATO': 0.35799, 'ETR': 0.01593, 'NI': 0.0, 'CNP': 0.23585, 'EME': 0.0, 'POWL': 0.00538, 'VRT': 0.0, 'PH': 0.03095, 'SMCI': 0.0, 'NXT': 0.0, 'ENLT': 0.0, 'GCPEF': 0.0, 'RUN': 0.0, 'ENRG.TA': 0.04635})

# %%
print(cleaned_weights_maxsharpe)
ef.portfolio_performance(verbose=True)
#2.99 Sharpe Ratio is extraordinary
#11.6% volatility is far less than S&P500 estimated 19-22% in 2025
#While Risk Adjusted returns are fantastic 60% of Portfolio is invested in Utilities, therefore cardinality constraint is needed
# Out:
# OrderedDict({'CRDO': 0.08116, 'AVGO': 0.01402, 'APH': 0.11971, 'NVDA': 0.00667, 'ALAB': 0.0, 'STLD': 0.0155, 'GXD.F': 0.0705, 'GMEXICOB.MX': 0.0, 'RS': 0.0, 'TECK': 0.0, 'ET': 0.0, 'ATO': 0.35799, 'ETR': 0.01593, 'NI': 0.0, 'CNP': 0.23585, 'EME': 0.0, 'POWL': 0.00538, 'VRT': 0.0, 'PH': 0.03095, 'SMCI': 0.0, 'NXT': 0.0, 'ENLT': 0.0, 'GCPEF': 0.0, 'RUN': 0.0, 'ENRG.TA': 0.04635})
# Expected annual return: 34.6%
# Annual volatility: 11.6%
# Sharpe Ratio: 2.99
# (np.float64(0.3456796426191439),
#  np.float64(0.11556439398187685),
#  np.float64(2.991229657409482))

# %%
ef_min = EfficientFrontier(mu, sigma)
raw_weights_minvol = ef_min.min_volatility()        #Finding the weights of the minimum volatility portfolio
cleaned_weights_minvol = ef_min.clean_weights()
print(raw_weights_minvol)
# Out:
# OrderedDict({'CRDO': 0.0, 'AVGO': 0.0, 'APH': 0.0928541043095798, 'NVDA': 0.0247760604989496, 'ALAB': 0.0, 'STLD': 0.0415664518146266, 'GXD.F': 0.0, 'GMEXICOB.MX': 0.0, 'RS': 0.1120648905726526, 'TECK': 0.0, 'ET': 0.1954941443210093, 'ATO': 0.2468141309561366, 'ETR': 0.0, 'NI': 0.019375224047121, 'CNP': 0.1850889453219305, 'EME': 0.0, 'POWL': 0.0117831320552719, 'VRT': 0.0, 'PH': 0.0268494874409526, 'SMCI': 0.0085670775865419, 'NXT': 0.0, 'ENLT': 0.0, 'GCPEF': 0.0, 'RUN': 0.0, 'ENRG.TA': 0.0347663510752276})

# %%
#Cardinality Constraint
from pypfopt import objective_functions

sector_map = port_data_25['valchain_industry'].to_dict()

ef_constrained = EfficientFrontier(mu, sigma, weight_bounds=(0.01, 1))    #14 stocks at 0 after L2 regularisation, min weight per stock 1%

ef_constrained.add_sector_constraints(sector_map, sector_lower={},
                                      sector_upper={'Semiconductors': 0.30,
                                                    'Metals and Mining': 0.30,
                                                    'Utilities': 0.30,
                                                    'Renewable Energy': 0.30,
                                                    'Data Center Infrastructure': 0.30})

ef_constrained.add_objective(objective_functions.L2_reg, gamma=0.1) #17 of 25 stocks were allocated 0 funds, L2 regularisation is added to penalise zero-weights and improve diversification

weights_final = ef_constrained.max_sharpe()
cleaned_final = ef_constrained.clean_weights()

print("--- Constrained Portfolio Weights ---")
print(cleaned_final)
print("\n--- Constrained Performance ---")
ef_constrained.portfolio_performance(verbose=True)

#2.39 Sharpe Ratio is great
#20.3% volatility matches S&P500 estimate of 19-22% in 2025
# Out:
# --- Constrained Portfolio Weights ---
# OrderedDict({'CRDO': 0.15731, 'AVGO': 0.02311, 'APH': 0.07504, 'NVDA': 0.01, 'ALAB': 0.01, 'STLD': 0.01, 'GXD.F': 0.14047, 'GMEXICOB.MX': 0.02818, 'RS': 0.01, 'TECK': 0.01, 'ET': 0.01, 'ATO': 0.09501, 'ETR': 0.07395, 'NI': 0.03785, 'CNP': 0.0832, 'EME': 0.01, 'POWL': 0.01, 'VRT': 0.01, 'PH': 0.05613, 'SMCI': 0.01, 'NXT': 0.01, 'ENLT': 0.06329, 'GCPEF': 0.01, 'RUN': 0.01, 'ENRG.TA': 0.03647})
#
# --- Constrained Performance ---
# Expected annual return: 48.5%
# Annual volatility: 20.3%
# Sharpe Ratio: 2.39
# /usr/local/lib/python3.12/dist-packages/pypfopt/efficient_frontier/efficient_frontier.py:259: UserWarning: max_sharpe transforms the optimization problem so additional objectives may not work as expected.
#   warnings.warn(
# (np.float64(0.48492893018544836),
#  np.float64(0.20256708666801468),
#  np.float64(2.3939176801224074))

# %% [markdown]
# **DCC-GARCH Dynamic Market Cap Adjusted Portfolio**
# ---
# ---

# %%
target_sector_weight = 0.20

shares = {}
for ticker in port_data_25_tickers:
    shares[ticker] = yf.Ticker(ticker).info.get('sharesOutstanding', 1)       #Shares Outstanding - metadata used to calculate Market Cap

def calculate_dynamic_weights(current_prices):
    weights = {}

    for industry in port_data_25['valchain_industry'].unique():
        industry_stocks = port_data_25[port_data_25['valchain_industry'] == industry].index

        mkt_caps = {t: current_prices[t] * shares[t] for t in industry_stocks}
        total_industry_cap = sum(mkt_caps.values())

        for t in industry_stocks:
            weights[t] = (mkt_caps[t] / total_industry_cap) * target_sector_weight #Stock Market Cap / Total Market Cap from same industry * 20% max allocation for industry

    return weights

start_weights = calculate_dynamic_weights(port_data_25_prices.iloc[0])      #1-1-2022 Price
end_weights = calculate_dynamic_weights(port_data_25_prices.iloc[-1])       #30-12-2025 Price

# %%
weight_shift = pd.DataFrame({
    'Start_Weight %': pd.Series(start_weights) * 100,
    'End_Weight %': pd.Series(end_weights) * 100
})

weight_shift['Change'] = weight_shift['End_Weight %'] - weight_shift['Start_Weight %']

print(weight_shift.sort_values(by='Change', ascending=False).head(5))   #Top 5 Changes
# Out:
#              Start_Weight %  End_Weight %    Change
# VRT                3.452974      5.413762  1.960788
# PH                 7.996904      9.659235  1.662331
# GMEXICOB.MX        7.902104      9.517782  1.615679
# ETR                3.685555      4.943959  1.258404
# AVGO               4.190390      5.146647  0.956257

# %%
def calculate_staggered_returns(df_prices, weights_dict):
    daily_rets = df_prices.pct_change()

    w_series = pd.Series(weights_dict)

    weighted_rets = daily_rets.mul(w_series, axis=1)    #If weight for stock in w_series is missing, weight will be 0

    available_weight = (daily_rets.notnull()).astype(int).mul(w_series, axis=1).sum(axis=1)  #Find total weight of assets available to invest in (excludes non-public stocks)
    portfolio_rets = weighted_rets.sum(axis=1) / available_weight         #ensure portfolio remains fully invested even if entire industries aren't public yet

    return portfolio_rets.fillna(0)

full_range_prices = port_data_25_prices.copy()          #Price Data used for DCC-GARCH MVO Expected Return
staggered_rets = calculate_staggered_returns(full_range_prices, cleaned_final)      #cleaned_final - weights from DCC-GARCH MVO Portfolio
full_growth = (1 + staggered_rets).cumprod() * 100          #Cumulative return starting with $100

# %%
dynamic_ann_ret = staggered_rets.mean() * 252

dynamic_ann_vol = staggered_rets.std() * np.sqrt(252)

rf=0          #Risk-Free Returns - usually assumed to be 0
dynamic_sharpe = (dynamic_ann_ret-rf) / dynamic_ann_vol
print(f"--- DCC-GARCH Dynamic Portfolio ---")
print(f"Annual Return: {dynamic_ann_ret:.2%}")
print(f"Volatility: {dynamic_ann_vol:.2%}")
print(f"Sharpe Ratio: {dynamic_sharpe:.2f}")
# Out:
# --- DCC-GARCH Dynamic Portfolio ---
# Annual Return: 47.39%
# Volatility: 22.25%
# Sharpe Ratio: 2.13

# %%
import matplotlib.pyplot as plt

benchmark = yf.download('^GSPC', start=full_growth.index[0], end=full_growth.index[-1])['Close']
benchmark_value = (benchmark / benchmark.iloc[0]) * 100

plt.figure(figsize=(12,6))
plt.plot(full_growth, label='DCC-GARCH AI Value Chain (Industry-Capped Mkt Cap)', color='blue', linewidth=2)
plt.plot(benchmark_value, label='S&P 500 (Market Benchmark)', color='grey', linestyle='--')
plt.ylabel('Value of $100 Investment')
plt.title('DCC-GARCH AI Value Chain Performance vs. S&P 500')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# /tmp/ipykernel_15111/4189876809.py:3: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   benchmark = yf.download('^GSPC', start=full_growth.index[0], end=full_growth.index[-1])['Close']
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# **Fractional (1/2) Kelly Criterion Portfolio Growth vs EGARCH Dynamic Portfolio Growth**
# ---
# ---

# %%
kelly_returns = np.log(full_range_prices / full_range_prices.shift(1)).dropna() #Log (continuous compounded returns) of todays value / yesterdays value (=growth_ratio)
                                                                                #Growth ratio > 1 (portfolio grew in value), < 1 (shrunk)
mu = kelly_returns.mean() * 252
sigma = kelly_returns.cov() * 252

kelly_mu = mu.values
kelly_sigma = sigma.values      #Changes to numpy array for numpy library use (matrix multiplication)

# %%
kelly_weights = np.linalg.inv(kelly_sigma) @ kelly_mu       #Raw Kelly Portfolio weights, @=matrix multiplication
                                                            #Cov matrix kelly_sigma finds stocks moving together, inverse eliminates this rewarding diversification
kelly_weights = kelly_weights / np.sum(np.abs(kelly_weights))    #Scaled so weights add up to 1
                                                                #Weights can appear as negative to indicate shorting the stock, so removed with np.abs()
half_kelly_weights = kelly_weights * 0.5     #Fractional Kelly (1/2) is used in industry to reduce drawdowns, or large losses

# %%
kport_ret = half_kelly_weights @ kelly_mu
kport_vol = np.sqrt(half_kelly_weights @ kelly_sigma @ half_kelly_weights)

# %%
growth_rate = kport_ret - 0.5 * kport_vol**2       #Variable Kelly Criterion is built to maximise
print(str(np.round(growth_rate, 4) * 100) + '%')    #9% Log Compound Growth Rate, matches S&P500 average
# Out:
# 9.42%

# %%
dynamic_w_array = np.array([start_weights[t] for t in kelly_returns.columns])
d_ret = dynamic_w_array @ kelly_mu
d_vol = np.sqrt(dynamic_w_array @ kelly_sigma @ dynamic_w_array)
d_growth = d_ret - 0.5 * d_vol**2
print(str(np.round(d_growth, 4) * 100) + '%')       #14% Log Compound Growth Rate, good
# Out:
# 14.05%

# %%
print(str(np.round(d_vol, 4) * 100) + '%')
# Out:
# 20.7%

# %% [markdown]
# **DCC-GARCH HRP Portfolio**
# ---
# ---

# %%
stock_data_usd = pd.read_csv(url, index_col=0, parse_dates=True)

stock_ret = stock_data_usd.pct_change()
# Out:
# /tmp/ipykernel_15111/3806145748.py:3: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   stock_ret = stock_data_usd.pct_change()

# %%
day_1_trading = stock_ret.iloc[2].notnull()
full_history_stocks = day_1_trading[day_1_trading].index      #Keeping only stocks with full trading history over 4 years as NaN/0 values ruin HRP math

full_stock_ret = stock_ret[full_history_stocks]
full_stock_ret.dropna(inplace=True)
full_stock_ret.shape
# Out:
# /tmp/ipykernel_15111/3444010170.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_stock_ret.dropna(inplace=True)
# (1239, 126)

# %%
# hrp_dist_model = mgarch.mgarch()
# hrp_dist_model.fit(full_stock_ret)

# hrp_prediction = hrp_dist_model.predict(1)
# hrp_dcc_cov = hrp_prediction['cov']

# hrp_dcc_vols = np.sqrt(np.diag(hrp_dcc_cov))
# hrp_dcc_corr = hrp_dcc_cov / np.outer(hrp_dcc_vols, hrp_dcc_vols)

# hrp_dcc_corr_df = pd.DataFrame(hrp_dcc_corr, index=full_history_stocks, columns=full_history_stocks)

# %%
# !pip install PyPortfolioOpt
from pypfopt import risk_models
from pypfopt import expected_returns
from pypfopt import HRPOpt

# hrp = HRPOpt(returns=None, cov_matrix=hrp_dcc_corr_df)
# hrp_weights = hrp.optimize()

# clean_hrp_weights = hrp.clean_weights()
# Out:
# Requirement already satisfied: PyPortfolioOpt in /usr/local/lib/python3.12/dist-packages (1.6.0)
# Requirement already satisfied: cvxpy>=1.1.19 in /usr/local/lib/python3.12/dist-packages (from PyPortfolioOpt) (1.6.7)
# Requirement already satisfied: numpy<3.0.0,>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from PyPortfolioOpt) (2.0.2)
# Requirement already satisfied: pandas<4.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from PyPortfolioOpt) (2.2.2)
# Requirement already satisfied: scikit-base<0.14.0 in /usr/local/lib/python3.12/dist-packages (from PyPortfolioOpt) (0.13.2)
# Requirement already satisfied: scikit-learn>=0.24.1 in /usr/local/lib/python3.12/dist-packages (from PyPortfolioOpt) (1.6.1)
# Requirement already satisfied: scipy>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from PyPortfolioOpt) (1.16.3)
# Requirement already satisfied: osqp>=0.6.2 in /usr/local/lib/python3.12/dist-packages (from cvxpy>=1.1.19->PyPortfolioOpt) (1.1.1)
# Requirement already satisfied: clarabel>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from cvxpy>=1.1.19->PyPortfolioOpt) (0.11.1)
# Requirement already satisfied: scs>=3.2.4.post1 in /usr/local/lib/python3.12/dist-packages (from cvxpy>=1.1.19->PyPortfolioOpt) (3.2.11)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<4.0.0,>=1.0.0->PyPortfolioOpt) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<4.0.0,>=1.0.0->PyPortfolioOpt) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<4.0.0,>=1.0.0->PyPortfolioOpt) (2026.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.24.1->PyPortfolioOpt) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.24.1->PyPortfolioOpt) (3.6.0)
# Requirement already satisfied: cffi in /usr/local/lib/python3.12/dist-packages (from clarabel>=0.5.0->cvxpy>=1.1.19->PyPortfolioOpt) (2.0.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from osqp>=0.6.2->cvxpy>=1.1.19->PyPortfolioOpt) (3.1.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from osqp>=0.6.2->cvxpy>=1.1.19->PyPortfolioOpt) (75.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas<4.0.0,>=1.0.0->PyPortfolioOpt) (1.17.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi->clarabel>=0.5.0->cvxpy>=1.1.19->PyPortfolioOpt) (3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->osqp>=0.6.2->cvxpy>=1.1.19->PyPortfolioOpt) (3.0.3)

# %%
# import matplotlib.pyplot as plt
# from pypfopt import plotting

# plt.figure(figsize=(12, 6))
# plotting.plot_dendrogram(hrp)
# plt.title("HRP Dendrogram: The Clusters of the AI Universe")
# plt.show()

# %%
# hrp_weights_series = pd.Series(clean_hrp_weights).sort_values(ascending=False)
# print(hrp_weights_series.head(25))

# %%
# top_25_hrp_tickers = hrp_weights_series.head(25).index

# top_25_weights = hrp_weights_series.head(25)

# top_25_final_weights = top_25_weights / top_25_weights.sum()

# print(top_25_final_weights)

# %%
# hrp_w_series = pd.Series(top_25_final_weights)

# hrp_daily_rets = full_stock_ret.mul(hrp_w_series, axis=1).sum(axis=1)

# hrp_growth = (1 + hrp_daily_rets).cumprod() * 100

# %%
# benchmark = yf.download('^GSPC', start=hrp_daily_rets.index[0], end=hrp_daily_rets.index[-1])['Close']
# benchmark_value = (benchmark / benchmark.iloc[0]) * 100

# plt.figure(figsize=(12,6))
# plt.plot(hrp_growth, label='DCC-GARCH Pure HRP Top 25 Weights', color='blue', linewidth=2)
# plt.plot(benchmark_value, label='S&P 500 (Market Benchmark)', color='grey', linestyle='--')
# plt.ylabel('Value of $100 Investment')
# plt.title('DCC-GARCH Pure HRP Top 25 Weights Performance vs. S&P 500')
# plt.legend()
# plt.grid(True, alpha=0.3)
# plt.show()

# %%
# hrp_ann_ret = hrp_daily_rets.mean() * 252
# hrp_ann_vol = hrp_daily_rets.std() * np.sqrt(252)
# hrp_sharpe = hrp_ann_ret / hrp_ann_vol

# print(f"--- DCC-GARCH Pure HRP Portfolio ---")
# print(f"DCC-GARCH Pure HRP Annual Return: {hrp_ann_ret:.2%}")
# print(f"DCC-GARCH Pure HRP Volatility: {hrp_ann_vol:.2%}")
# print(f"DCC-GARCH Pure HRP Sharpe Ratio: {hrp_sharpe:.2f}")

# %% [markdown]
# **DCC-GARCH HRP Hybrid Portfolio**
# ---
# ---

# %%
v2_tickers = ["AVGO", "APH", "NVDA",        # Semiconductors
              "STLD", "ANTO.L", "GMEXICOB.MX", "RS", "TECK", # Metals and Mining
              "ET", "ATO", "ETR", "NI", "CNP",               # Utilities
              "EME", "POWL", "PWR", "VRT", "PH",             # Data Center Infrastructure
              "RUN", "CSIQ"        # Renewable Energy
              ]

# %%
hrp_dist_model = mgarch.mgarch()
hrp_dist_model.fit(full_stock_ret[v2_tickers])        #Stock returns for v2_tickers

hrp_prediction = hrp_dist_model.predict(1)
hrp_dcc_cov = hrp_prediction['cov']

hrp_dcc_vols = np.sqrt(np.diag(hrp_dcc_cov))
hrp_dcc_corr = hrp_dcc_cov / np.outer(hrp_dcc_vols, hrp_dcc_vols)

hrp_dcc_corr_df = pd.DataFrame(hrp_dcc_corr, index=v2_tickers, columns=v2_tickers)      #Eliminating 20 minute runtime by only calculating for v2_tickers

# %%
dcc_hybrid_corr_df = hrp_dcc_corr_df.loc[v2_tickers, v2_tickers]    #Chosen tickers must include row and column

hrp_hybrid = HRPOpt(returns=None, cov_matrix=dcc_hybrid_corr_df)  #'CRDO', 'ALAB', 'NXT', 'ENLT', 'ENRG.TA' don't have full 4 year data, so removed
hybrid_weights = hrp_hybrid.optimize()

# %%
hybrid_w_series = pd.Series(hybrid_weights)
hybrid_daily_rets = full_stock_ret[v2_tickers].mul(hybrid_w_series, axis=1).sum(axis=1)

hrp_hybrid_growth = (1 + hybrid_daily_rets).cumprod() * 100

# %%
benchmark = yf.download('^GSPC', start=hybrid_daily_rets.index[0], end=hybrid_daily_rets.index[-1])['Close']
benchmark_value = (benchmark / benchmark.iloc[0]) * 100

plt.figure(figsize=(12,6))
plt.plot(hrp_hybrid_growth, label='HRP Hybrid', color='blue', linewidth=2)
plt.plot(benchmark_value, label='S&P 500 (Market Benchmark)', color='grey', linestyle='--')
plt.ylabel('Value of $100 Investment')
plt.title('HRP Hybrid Performance vs. S&P 500')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# /tmp/ipykernel_15111/1089074248.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   benchmark = yf.download('^GSPC', start=hybrid_daily_rets.index[0], end=hybrid_daily_rets.index[-1])['Close']
# [*********************100%***********************]  1 of 1 completed

# %%
hybrid_ann_ret = hybrid_daily_rets.mean() * 252
hybrid_ann_vol = hybrid_daily_rets.std() * np.sqrt(252)                 #Performance when fitted on 20 AI Value Chain stocks from V2
hybrid_sharpe = hybrid_ann_ret / hybrid_ann_vol

print(f"--- DCC-GARCH Hybrid HRP Portfolio ---")                        #DCC-GARCH Hybrid (with DCC-GARCH fitted on 126 stocks) Performance (removed due to 20min time)
print(f"DCC-GARCH Hybrid HRP Annual Return: {hybrid_ann_ret:.2%}")      #24.06%
print(f"DCC-GARCH Hybrid HRP Volatility: {hybrid_ann_vol:.2%}")         #18.82%
print(f"DCC-GARCH Hybrid HRP Sharpe Ratio: {hybrid_sharpe:.2f}")        #1.28
# Out:
# --- DCC-GARCH Hybrid HRP Portfolio ---
# DCC-GARCH Hybrid HRP Annual Return: 23.55%
# DCC-GARCH Hybrid HRP Volatility: 20.00%
# DCC-GARCH Hybrid HRP Sharpe Ratio: 1.18
